# %% [markdown]
# # textaCy (version 0.6.2)
# ## textaCy is our first NLP preprocessing library with sophisticated statistical analyses, and  abstract applications, such as n-grams, and vectorization. Very useful in preparing data for ML.
# ## Pros: textaCy is fast, efficient and has a wide variety of functions; it is built on spaCy; it has a high level of abstraction, so we can control our ML through preprocessing.
# ## Cons: named entity extraction doesn't work for our (untrained) dataset ;(

# %%
import pandas as pd
import es_core_news_md
import textacy
import spacy
import csv

# %%
def fetch_dataset(csv_file_name):
    data = pd.read_csv(csv_file_name, sep=',')

    return data

# %%
handle = fetch_dataset('mattermost_running.csv')
mess = handle['text'].to_string()
#must be a string for textacy
print(type(mess))
# Out:
# <class 'str'>

# %% [markdown]
# ### a textaCy-style keyword search.

# %%
#look for keywords in the text
def keyword_search(keyword):
    feedback = textacy.text_utils.KWIC(mess, keyword, window_width=35)
    return feedback

# %%
keyword_search('poliza')
# Out:
# además necesitaría una copia de la  poliza
# 12     Hola estoy en la pagina web
# or favor necesito que me envíen la  poliza . Es...
# 29        deseo consultarle
# a con ustedes pero se me venció la  poliza
# 98            Es saber si podía ha
# a con ustedes pero se me venció la  poliza
# 104           Es saber si podía ha
# a con ustedes pero se me venció la  poliza
# 121           Es saber si podía ha
# ola quisiera saber cuando vence la  poliza
# 149           Hola quisiera saber
# ola quisiera saber cuando vence la  poliza
# 150               si x favor manda

# %% [markdown]
# ## Convert our text data into a .Doc to tokenize and analyze our data on a higher level

# %%
#no need to tell it the language. Textacy already knows!
doc = textacy.Doc(mess)
doc
# Out:
# Doc(3000 tokens; "0      hola necesito conocer sobre precios de s...")

# %% [markdown]
# ## textacy.text_stats

# %%
#if we convert the doc to .TextStats we can get some statistics, easy and fast
stats = textacy.TextStats(doc)

# %%
stats.basic_counts
# Out:
# {'n_chars': 8755,
#  'n_long_words': 307,
#  'n_monosyllable_words': 1206,
#  'n_polysyllable_words': 340,
#  'n_sents': 126,
#  'n_syllables': 3574,
#  'n_unique_words': 825,
#  'n_words': 2168}

# %%
#unique words
stats.n_unique_words
# Out:
# 825

# %% [markdown]
# ## textacy.extract:  here's a list of some of the things we can extract

# %%
"""
>words(doc, filter_stops=True, filter_punct=True, filter_nums=False, include_pos=None, exclude_pos=None, min_freq=1):
>ngrams(doc, n, filter_stops=True, filter_punct=True, filter_nums=False, include_pos=None, exclude_pos=None, min_freq=1):
>named_entities(doc, include_types=None, exclude_types=None, drop_determiners=True, min_freq=1):            
>noun_chunks(doc, drop_determiners=True, min_freq=1):
>subject_verb_object_triples(doc):
>acronyms_and_definitions(doc, known_acro_defs=None):
>direct_quotations(doc):
>pos_regex_matches(doc, pattern):
---Examples of POS_REGEX_PATTERNS``):
            * noun phrase: r'<DET>? (<NOUN>+ <ADP|CONJ>)* <NOUN>+'
            * compound nouns: r'<NOUN>+'
            * verb phrase: r'<VERB>?<ADV>*<VERB>+'
            * prepositional phrase: r'<PREP> <DET>? (<NOUN>+<ADP>)* <NOUN>+' """

# %% [markdown]
# ### What about Stopwords? textaCy filters stopwords at the moment of extracting, rather than creating a new object without stopwords, as we have to do with spaCy and NLTK. This saves time!

# %%
#let's start with n-grams (in this case trigrams)
ngrams = list(textacy.extract.ngrams(doc, 3, filter_stops=True, filter_punct=True))
ngrams
# Out:
# [precios de seguro,
#  o posible cliente,
#  necesito una cotizacion,
#  Hice el pago,
#  Y me e,
#  imprimir mi cupon,
#  cupon de pago,
#  Me envia a,
#  a la pagina,
#  pagina de mercado,
#  mercado pago y,
#  y me pide,
#  Toco el boton,
#  medios de pagos,
#  imprimir mi cupon,
#  cupon de pago,
#  Me envia a,
#  a la pagina,
#  pagina de mercado,
#  mercado pago y,
#  y me pide,
#  Toco el boton,
#  medios de pagos,
#  venció el seguro,
#  necesitaría una copia,
#  pagina web y,
#  web y quiero,
#  viene la grúa,
#  Ya pasaron 2,
#  Assistance no aparece,
#  y para servir,
#  Gente necesitamos ayuda,
#  Pablo bustos fierro,
#  seguro a presentar,
#  presentar la boleta,
#  Luis de Cabrera,
#  pague con débito,
#  débito on Line,
#  envíen la poliza,
#  pagina web y,
#  web y quiero,
#  esperando q inda,
#  inda me conteste,
#  mande al grupo,
#  anulada por falta,
#  falta de pago,
#  SE LO HAGO,
#  verifico con day,
#  pagina web y,
#  web y quiero,
#  pagina web y,
#  web y quiero,
#  asegurar mi vehículo,
#  Esa me interesa,
#  Ford f 100,
#  f 100 modelo,
#  100 modelo 80,
#  paso los datos,
#  datos o foto,
#  tarjeta de credito,
#  enviar una cotizacion,
#  cotizacion por favor,
#  promo para Julio,
#  envio una imagen,
#  Hola Te respondo,
#  respondo desde aca,
#  visitar el lunes,
#  gustavo.lolli added to,
#  added to the,
#  to the channel,
#  the channel by,
#  channel by user,
#  user updated the,
#  updated the channel,
#  the channel display,
#  channel display name,
#  display name from,
#  envianos una foto,
#  envio la cotizacion,
#  user joined the,
#  joined the channel,
#  usuaruario que veo,
#  Ah bien!entonces Fernando,
#  bien!entonces Fernando Placios,
#  Fernando Placios vendria,
#  Placios vendria a,
#  user updated the,
#  updated the channel,
#  the channel display,
#  channel display name,
#  display name from,
#  user joined the,
#  joined the channel,
#  user joined the,
#  joined the channel,
#  jajajajajaja salen fritas,
#  asegurar un automovil,
#  Es un regata,
#  cotizar mi auto,
#  Es un ford,
#  ford ka1.3 mod,
#  Yo quería hacerle,
#  hacerle un seguro,
#  a mi auto,
#  pasas los precios,
#  cotizar mi auto,
#  Es un ford,
#  ford ka1.3 mod,
#  Quería averiguar x,
#  x un seguro,
#  venció la poliza,
#  Mi patente ab235,
#  patente ab235 Pv,
#  Yo quería hacerle,
#  hacerle un seguro,
#  a mi auto,
#  pasas los precios,
#  Quería averiguar x,
#  x un seguro,
#  venció la poliza,
#  Mi patente ab235,
#  patente ab235 Pv,
#  Necesitaría el nombr,
#  Tengo el nombre,
#  y el número,
#  número de documento,
#  documento del c,
#  Necesitó la boleta,
#  pagar mi seguro,
#  Necesitaría el cupón,
#  cupón para abonar,
#  abonar el mes,
#  Necesitó la boleta,
#  pagar mi seguro,
#  Me podes responder,
#  tratando de contac,
#  Tengo un auto,
#  auto Ford facon,
#  Ford facon modelo,
#  facon modelo 1983,
#  modelo 1983 y,
#  1983 y quería,
#  nombre es Natalia,
#  Quería averiguar x,
#  x un seguro,
#  venció la poliza,
#  Mi patente ab235,
#  patente ab235 Pv,
#  Me podes responder,
#  tratando de contac,
#  enviarme el link,
#  link de pago,
#  baja mi seguro,
#  Ya estoy asegurado,
#  seguro de accidente,
#  y además quiero,
#  centro por favor,
#  seguro de accidente,
#  y además quiero,
#  centro por favor,
#  seguro de accidente,
#  y además quiero,
#  centro por favor,
#  Tranqui chiquita nomas,
#  Tranqui chiquita nomas,
#  hice el trámite,
#  trámite por teléfono,
#  Tengo un auto,
#  auto Ford facon,
#  Ford facon modelo,
#  facon modelo 1983,
#  modelo 1983 y,
#  1983 y quería,
#  Me lamo Natalia,
#  vence la poliza,
#  vence la poliza,
#  x favor mandame,
#  sale los datos,
#  datos x q,
#  Sres de organización,
#  doy un numero,
#  numero x q,
#  quedando sin bat,
#  Cuentan con seguro,
#  seguro para bicicletas,
#  El evento ocurrió,
#  ocurrió el 23,
#  asegurar un vehículo,
#  vehículo contra tercero,
#  En qué dirección,
#  Tuve que contratar,
#  contratar un flete,
#  porq no m,
#  Así que decime,
#  llevo la boleta,
#  doy de baja,
#  quiero un seguro,
#  Quiero esa promocion,
#  seguro para autos,
#  Algo mas completo,
#  A ver coméntame,
#  coméntame precio cobertura,
#  precio cobertura etc,
#  Robo parcial o,
#  consiste la categoria,
#  consiste la categoria,
#  sale para asegurar,
#  asegurar un gol,
#  gol power mod,
#  power mod 2011,
#  nesecito para mañana,
#  cosa te aviso,
#  Estoy comparando precios,
#  llamaron para renovar,
#  renovar el seguro,
#  y me d,
#  encanta la premura,
#  premura para contestar,
#  llamaron me pas,
#  llamaron para renovar,
#  renovar el seguro,
#  y me d,
#  encanta la premura,
#  premura para contestar,
#  llamaron me pas,
#  costo cual seria,
#  mira ayer pase,
#  pase las fotos,
#  Hola buenas tardes,
#  Alberto fui a,
#  a una sucursal,
#  Ponían mí número,
#  número de documento,
#  documento y salía,
#  salía otro nombre,
#  genial mi correo,
#  electrónico es carol,
#  Me pueden pasar,
#  pasar x favor,
#  x favor marca,
#  favor marca y,
#  marca y modelo,
#  modelo del aut,
#  Me lo piden,
#  seguro x favor,
#  q le conté,
#  q me chocó,
#  chocó de atrás,
#  Hay alguna sucursal,
#  sucursal para abonar,
#  abonar por Rapipago,
#  El lunes paso,
#  pasar un auto,
#  Es un VW,
#  VW gol 1.6,
#  gol 1.6 5,
#  1.6 5 ptas,
#  5 ptas 2008,
#  2008 con GNC,
#  GNC está radi,
#  Y en SanCor,
#  La segunda o,
#  Quiero algo completo,
#  Cuando me decís,
#  Y en SanCor,
#  La segunda o,
#  Cuando me decís,
#  Y en SanCor,
#  La segunda o,
#  Quiero algo completo,
#  Cuando me decís,
#  recuerden a nombre,
#  nombre de quevedo,
#  Como puedo pagar,
#  pense q seria,
#  q seria 690,
#  renovación del seguro,
#  seguro contra terceros,
#  terceros le co,
#  pasa es q,
#  rio cuarto y,
#  y no tie,
#  pense q seria,
#  q seria 690,
#  renovación del seguro,
#  seguro contra terceros,
#  terceros le co,
#  pasa es q,
#  rio cuarto y,
#  y no tie,
#  den el link,
#  link de pago,
#  den el link,
#  link de pago,
#  q me tas,
#  paso las fotos,
#  q me tas,
#  cotizar por líder,
#  Esta tarde paso,
#  envio la cotización,
#  mandarme la voleta,
#  mandarme la voleta,
#  Se puede adherirse,
#  adherirse el débito,
#  a mi CBU,
#  mandarme la voleta,
#  mandarme la voleta,
#  pagar con débito,
#  pagar la voleta,
#  mandarme la voleta,
#  mandarme la voleta,
#  pagar la voleta,
#  Clio 2 modelo,
#  2 modelo 2009,
#  denuncia un vehículo,
#  qe tiene l,
#  Te puedo mandar,
#  mandar la foto,
#  puerta con vidri,
#  Perdón la demora,
#  salir el auto,
#  auto entero y,
#  Disculpa la insistencia,
#  insistencia salgo a,
#  modelo de lancha,
#  Una Nueva respuesta,
#  respuesta desde mattermost,
#  Luna te respondo,
#  respondo desde mattermost,
#  respondo desde acá,
#  pasame una bandera,
#  uh de lujo,
#  bonito tu auto,
#  Mandame una foto]

# %%
#Let's try named entities
entit = list(textacy.extract.named_entities(doc, drop_determiners=True))
print(len(entit))
# Out:
# 456

# %%
#entity labels
myents = {}
ents = []
label = []
for en in entit:
    myents[en] = en.label_
for key,val in myents.items():
    ents.append(key)
    label.append(val)
print(len(label))
# Out:
# 456

# %%
#Let's viz ...
df = pd.DataFrame({'entity' : ents, 
                  'label' : label})
df
# Out:
#                                                 entity label
# 0                                                 (\n)   ORG
# 1                                                 (\n)   ORG
# 2                                            (\n, 280)  MISC
# 3    (                                               )   ORG
# 4                                  (Perfecto, !, !, !)  MISC
# 5                                            (\n, 112)  MISC
# 6                                                 (\n)   ORG
# 7                                        (Perfecto, !)  MISC
# 8                         (                          )  MISC
# 9                                            (\n, 249)  MISC
# 10                                                (\n)   ORG
# 11                                                (\n)   ORG
# 12                                            (\n, 36)  MISC
# 13                                       (Necesitaría)   ORG
# 14                      (                            )   ORG
# 15                                           (\n, 204)  MISC
# 16                                           (\n, 130)  MISC
# 17                                            (Quería)  MISC
# 18                                            (nombre)  MISC
# 19                                    (Buenas, tardes)  MISC
# 20                                                (Te)  MISC
# 21                                                (\n)   ORG
# 22                                                (\n)   ORG
# 23                                              (    )  MISC
# 24                                                (\n)   ORG
# 25                                           (\n, 163)  MISC
# 26                                            (\n, 64)  MISC
# 27                                            (Quiero)   LOC
# 28                                                (\n)  MISC
# 29                                         (Rivadavia)   LOC
# ..                                                 ...   ...
# 426                                         (Necesitó)  MISC
# 427                                               (\n)   ORG
# 428                                    (Atte, \n, 174)   PER
# 429                               (Gente, necesitamos)  MISC
# 430                                           (Quería)  MISC
# 431                                               (\n)   ORG
# 432             (                            , Quiero)   ORG
# 433                                               (\n)   ORG
# 434                     ( , caminera, t, ..., \n, 152)  MISC
# 435                                               (\n)   ORG
# 436                                   (Buenas, tardes)  MISC
# 437                                               (\n)   ORG
# 438                                             (    )  MISC
# 439                                              (GNC)  MISC
# 440                                        (Yo, tenía)  MISC
# 441                                           (Quiero)   LOC
# 442                                             ( , 1)  MISC
# 443                                          (\n, 187)  MISC
# 444                                               (\n)   ORG
# 445                                               (\n)   ORG
# 446                                          (\n, 102)  MISC
# 447                                               (\n)   ORG
# 448                                               (\n)   ORG
# 449                                               (\n)   ORG
# 450                                               (\n)   ORG
# 451                                    (       , Hola)   LOC
# 452                                               (\n)  MISC
# 453                                               (\n)   ORG
# 454                                          (\n, 191)  MISC
# 455                                           (\n, 24)  MISC
#
# [456 rows x 2 columns]

# %% [markdown]
# ### Named entity extraction performs as poorly in textaCy as in spaCy, probably because they are both using the same algorithm.

# %%
import textacy.keyterms

# %% [markdown]
# # textaCy keyterms: a step towards ML
# ## With textaCy keyterms we can see how our words will be processed in ML: these numerical rankings assigned are the same that will be used in our tf-idf vectorization.

# %%
# output reveals keywords, like from before, but with a numerical ranking, the same numerical 
textacy.keyterms.sgrank(doc, ngrams=(1, 2, 3, 4), normalize='lemma', window_width=1500, n_keyterms=10, idf=None)
# Out:
# [('seguro', 0.19278695357946754),
#  ('Hola', 0.12481885409310207),
#  ('user joined', 0.10946179157848471),
#  ('paginar web', 0.0550999266727019),
#  ('Quiero', 0.05480748216303773),
#  ('pagar', 0.050713555207169275),
#  ('gracia', 0.029431723259660005),
#  ('favor', 0.028356676186600118),
#  ('precio', 0.024231605372670127),
#  ('poliza', 0.024204858512917652)]

# %%
textacy.keyterms.sgrank(doc, ngrams=(2, 3), normalize='lemma', window_width=1500, n_keyterms=10, idf=None)
# Out:
# [('user joined', 0.7439178671590614), ('paginar web', 0.2560821328409387)]

# %% [markdown]
# ## textaCy Bag of Terms:

# %%
b_o_t = doc.to_bag_of_terms(ngrams=1, named_entities=True, as_strings=True)
sorted(b_o_t.items(), key=lambda x: x[1], reverse=True)[:15]
# Out:
# [('', 197),
#  ('seguro', 33),
#  ('y', 29),
#  ('Hola', 27),
#  ('pagar', 22),
#  ('a', 20),
#  ('Me', 18),
#  ('auto', 16),
#  ('q', 15),
#  ('Quiero', 15),
#  ('querer', 14),
#  ('favor', 12),
#  ('Quería', 10),
#  ('voleta', 10),
#  ('Es', 10)]

# %% [markdown]
# ## We will save vectorization for the next notebook on scikit learn and ML.
