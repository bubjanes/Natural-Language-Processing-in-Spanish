# %%
import csv
import pandas as pd
import spacy
import es_core_news_md

# %%
def fetch_dataset(csv_file_name):
    data = pd.read_csv(csv_file_name, sep=',')
    text=data
    return text

# %%
#INSERT THE FILE NAME BETWEEN THE PARENTHESIS
fetch_dataset()
# Out:
#                                                   text   creation_date
# 0    hola necesito conocer sobre precios de seguro ...     2/8/19 9:56
# 1                Hola soy un cliente o posible cliente    2/8/19 11:26
# 2    necesito una cotizacion de un seguro para mi E...    2/8/19 11:28
# 3    Buenas tardes. Si. Hice el pago online. Y me e...    2/8/19 13:50
# 4          Quiero imprimir mi cupon de pago y no puedo    2/9/19 10:35
# 5    Me envia a la pagina de mercado pago y me pide...    2/9/19 10:36
# 6    Toco el boton donde dice otros medios de pagos...    2/9/19 10:37
# 7          Quiero imprimir mi cupon de pago y no puedo    2/9/19 11:33
# 8    Me envia a la pagina de mercado pago y me pide...    2/9/19 11:33
# 9    Toco el boton donde dice otros medios de pagos...    2/9/19 11:33
# 10   estoy de vacaciones y se me venció el seguro. ...    2/9/19 11:34
# 11           además necesitaría una copia de la poliza    2/9/19 11:34
# 12   Hola estoy en la pagina web y quiero hacer una...   2/10/19 20:02
# 13                            No viene la grúa todavía   2/10/19 21:23
# 14                                  Ya pasaron 2 horas   2/10/19 21:23
# 15                                Alguna respuesta????   2/10/19 21:25
# 16                     Universal Assistance no aparece   2/10/19 21:41
# 17   Para cobrar todo bien y para servir vergonzoso...   2/10/19 21:42
# 18                             Gente necesitamos ayuda   2/10/19 21:42
# 19                                        Vergüenza!!!   2/10/19 21:56
# 20                                 Estamos con un niño   2/10/19 21:56
# 21         Muchas gracias por la atención recibida!!!!   2/10/19 22:39
# 22                              Son extraordinarios!!!   2/10/19 22:39
# 23                                    Super eficientes   2/10/19 22:40
# 24   Hola buenos días...soy Pablo bustos fierro...e...    2/11/19 9:46
# 25      Hoy pasaré por el seguro a presentar la boleta    2/11/19 9:47
# 26   Si..escudo seguro... Jerónimo Luis de Cabrera ...    2/11/19 9:50
# 27   Hola buen dia ....pague con débito on Line.......   2/11/19 10:03
# 28   por favor necesito que me envíen la poliza. Es...   2/11/19 11:01
# 29      deseo consultarle por el precio de su servicio   2/11/19 17:45
# ..                                                 ...             ...
# 257                                 O pagar con débito  12/17/18 10:00
# 258  Puedo pagar con el numero de la voleta anterior ?  12/17/18 10:06
# 259  Por favor  necesito pagar la voleta estoy en B...  12/17/18 10:21
# 260                        Buen día tendrán novedades?  12/17/18 10:34
# 261  Hola buen dia podrían mandarme la voleta de es...  12/17/18 10:34
# 262  Hola buen dia podrían mandarme la voleta de es...  12/17/18 10:34
# 263  Puedo pagar con el numero de la voleta anterior ?  12/17/18 10:34
# 264  Por favor  necesito pagar la voleta estoy en B...  12/17/18 10:34
# 265  Buen día!! Quería consultar por el seguro para...  12/17/18 10:50
# 266                                              Autos  12/17/18 10:50
# 267  Si si es un Clio 2 modelo 2009. Yo ya tenía co...  12/17/18 11:42
# 268  Me podrías decir qué debo hacer para volver a ...  12/17/18 11:42
# 269  como hacer una denuncia un vehículo qe tiene l...  12/17/18 11:56
# 270  Te puedo mandar la foto de la puerta con vidri...  12/17/18 12:28
# 271                                   Perdón la demora  12/17/18 12:55
# 272               Bueno apenas lo tenga se lo envío!!!  12/17/18 12:55
# 273  El pago sería en efectivo a partir del mes que...  12/17/18 12:55
# 274  Díganme en cuanto me quedaría el valor del seg...  12/17/18 12:55
# 275  tiene que salir el auto entero y todas las fot...  12/17/18 13:16
# 276                             Hola, tenés novedades?  12/17/18 13:49
# 277  Disculpa la insistencia salgo a las cuatro del...  12/17/18 14:31
# 278                        que modelo de lancha tenés?   1/18/19 14:51
# 279               Una Nueva respuesta desde mattermost   1/15/19 18:57
# 280             Hola Luna te respondo desde mattermost    1/15/19 1:52
# 281                              Te respondo desde acá   1/18/19 20:04
# 282                                 pasame una bandera   1/28/19 15:05
# 283                                     excelente!!!!!   1/25/19 20:39
# 284                                         uh de lujo   1/28/19 15:04
# 285                                 muy bonito tu auto   1/28/19 17:51
# 286                        Mandame una foto de tu auto   1/28/19 15:34
#
# [287 rows x 2 columns]

# %%
nlp = spacy.load('es_core_news_md')
mydict = {}
pos = []
tokens = []
occurr = []

for sent in text:
    doc = nlp(sent)
    for token in doc:   
        mydict[token] = token.pos_
print("Number of tokens:", len(mydict))

for key,val in mydict.items():
    tokens.append(str(key))
    pos.append(val)
    occurr.append(int(1))
print("Three columns - python lists - preprocessed for your pandas dataframe: 'tokens', 'pos', and 'occurr'.")
# Out:
# Number of tokens: 2987
# Three columns - python lists - to make your pandas dataframe: 'tokens', 'pos', and 'occurr'.

# %%
#LET'S MAKE A DATA FRAME
df = pd.DataFrame({'TOKEN' : tokens, 
                  'POS' : pos,
                 'occurr' : occurr})
df.shape
# Out:
# (2987, 3)

# %%
pos_count = df.groupby('POS')['TOKEN'].nunique()
print('PART OF SPEECH BREAKDOWN')
pos_count.sort_values(ascending=False)
# Out:
# PART OF SPEECH BREAKDOWN
# POS
# NOUN     236
# VERB     202
# ADJ       86
# PROPN     57
# AUX       46
# ADV       45
# PRON      42
# DET       39
# ADP       28
# NUM       22
# PUNCT     14
# SCONJ     10
# CONJ       9
# INTJ       5
# SYM        1
# SPACE      1
# Name: TOKEN, dtype: int64

# %%
grup = df.groupby('POS')

# %%
def get_word_hist(part_of_speech):
    grup = g.get_group(part_of_speech)
    grup_sum = grup.groupby('TOKEN')['occurr'].sum()
    return grup_sum.sort_values(ascending=False)

# %%
#ENTER PART OF SPEECH ABBREVIATION YOU WANT TO COUNT
get_word_hist('ADJ')
# Out:
# TOKEN
# buen               7
# pago               7
# total              5
# anterior           5
# ..                 5
# segunda            4
# nuevo              4
# Buen               4
# seria              4
# seguro             4
# personal           3
# completo           3
# cuatrimestral      3
# dias               3
# patente            3
# tercero            3
# pagofacil          2
# buenos             2
# buenas             2
# nueva              2
# Buenas             2
# ka1.3              2
# pense              2
# cuarto             2
# asegurado          2
# aqui               2
# verde              2
# solo               2
# tenés              2
# chiquita           2
#                   ..
# posible            1
# primera            1
# radicado           1
# recibida           1
# regiria            1
# envianos           1
# salgo              1
# solicitada         1
# sr                 1
# unico              1
# urgente            1
# vergonzoso         1
# perfecto           1
# pendiente          1
# parcial            1
# pagarlo            1
# on                 1
# mejor              1
# mandame            1
# mal                1
# levantado          1
# irresponsables     1
# guardado           1
# verifico           1
# facil              1
# f100               1
# extraordinarios    1
# excelente          1
# envio              1
# genial             1
# Name: occurr, Length: 86, dtype: int64
